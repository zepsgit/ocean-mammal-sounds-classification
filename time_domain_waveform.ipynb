# %%
# %%capture thiscell
#hide output of this cell
# %run ./data_preparation.ipynb

# %% [markdown]
# ### Display the waveform of time-domain of each category

# %%
#sample one instance from every category
file_names_list=[]
common_name_list=[]
n=len(metadata)
for i in range(n):
    if metadata.iloc[i][2] not in common_name_list:
        common_name_list.append(metadata.iloc[i][2])
        file_names_list.append(metadata.iloc[i][0])
#print(file_names_list)

# %%
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt
path='../data/'+file_names_list[9]
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(path)
_ = librosa.display.waveshow(data,sr=sample_rate)
#ipd.Audio(path)

# %%
import numpy as np
framerate = 44100
t = np.linspace(0,5,framerate*5)
data = np.sin(2*np.pi*220*t) + np.sin(2*np.pi*224*t)
ipd.Audio(data, rate=framerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("http://www.nch.com.au/acm/8k16bitpcm.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio("https://cis.whoi.edu/science/B/whalesounds/WhaleSounds/66038005.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
