# %% [markdown]
# ### Apply Fourier transformation on the time-domain waveform
# Plot different spectrums of different samples from the same category

# %%
# %%capture thiscell
#hide output of this cell
# %run ./time_domain_waveform.ipynb

# %%
# for i in range(size_file_names_list):
#     path='../data/'+file_names_list[i]
#     plt.figure(figsize=(12,4))
#     plt.title(common_name_list[i])
#     data,sample_rate = librosa.load(path)
#     _ = librosa.display.waveshow(data,sr=sample_rate)
#     ipd.Audio(path)
#for i in range(1,10,2):
import numpy as np
import math
for i in [2,4,5,6,7,60,62,65,66,100,102,104,105,150,162,156,164,165,168]:
    path='../data/'+metadata.file_name[i]
    data,sample_rate = librosa.load(path)
    plt.figure(figsize=(12,4))
    plt.title(metadata.common_name[i])
    sp = np.fft.fft(data)
    freq = np.fft.fftfreq(data.shape[-1])
    A=np.sqrt(np.square(sp.real)+np.square(sp.imag))
    plt.plot(freq, A)

# %%
t = np.arange(256)
data.shape[-1]
# Out:
# 77793
